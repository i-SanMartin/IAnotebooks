# %% [markdown]
# <a href="https://colab.research.google.com/github/i-SanMartin/IAnotebooks/blob/main/IA_Notebook%233.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy as sc

import matplotlib.pyplot as plt

# %%
func = lambda th: np.sin(1 / 2 * th[0] ** 2 - 1 / 4 * th[1] ** 2 + 3) * np.cos(2 * th[0] + 1 - np.e ** th[1])

#Representamos el plano de nuestra funcion
res=100
_X = np.linspace(-2, 2, res)
_Y = np.linspace(-2, 2, res)
_Z = np.zeros((res, res))

for ix, x in enumerate(_X):
  for iy, y in enumerate(_Y):
    _Z[iy, ix] = func([x, y])

plt.contourf(_X, _Y, _Z, 100)

#Camos a dibujar un punt aleatorio
Theta = np.random.rand(2) * 4 - 2

_T = np.copy(Theta)
plt.plot(Theta[0], Theta [1], "o", c="white")
h = 0.001
grad = np.zeros(2)
lr = 0.01

for i in range(1000):
  for it, th in enumerate(Theta):
    _T = np.copy(Theta)
    _T[it] += h
    deriv = (func(_T) - func(Theta)) / h
    grad[it] = deriv

  Theta -= grad * lr
  if (i % 100 == 0):
    plt.plot(Theta[0], Theta [1], "o", c="red")
plt.plot(Theta[0], Theta [1], "o", c="green")
plt.show()
