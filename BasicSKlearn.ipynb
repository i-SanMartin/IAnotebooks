# %% [markdown]
# <a href="https://colab.research.google.com/github/i-SanMartin/IAnotebooks/blob/main/BasicSKlearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt

from sklearn.datasets import make_circles

# Creamos nuestros datos artificiales, donde buscaremos clasificar 
# dos anillos concéntricos de datos. 
X, Y = make_circles(n_samples=500, factor=0.5, noise=0.05)

# Resolución del mapa de predicción.
res = 100 

# Coordendadas del mapa de predicción.
_x0 = np.linspace(-1.5, 1.5, res)
_x1 = np.linspace(-1.5, 1.5, res)

# Input con cada combo de coordenadas del mapa de predicción.
_pX = np.array(np.meshgrid(_x0, _x1)).T.reshape(-1, 2)

# Objeto vacio a 0.5 del mapa de predicción.
_pY = np.zeros((res, res)) + 0.5

# Visualización del mapa de predicción.
plt.figure(figsize=(8, 8))
plt.pcolormesh(_x0, _x1, _pY, cmap="coolwarm", vmin=0, vmax=1)

# Visualización de la nube de datos.
plt.scatter(X[Y == 0,0], X[Y == 0,1], c="skyblue")
plt.scatter(X[Y == 1,0], X[Y == 1,1], c="salmon")

plt.tick_params(labelbottom=False, labelleft=False)

# %%
import sklearn as sk
import sklearn.neural_network

lr = 0.01#learning rate
nn = [2, 16, 8, 1]

#Creamos el objeto de modelo, se pueden modificar algunos hiperparametros
modelo = sk.neural_network.MLPRegressor(solver='sgd',               #tipo de optimizador
                                        learning_rate_init=lr,      #learning rate inicial
                                        hidden_layer_sizes=nn[1:],  #número de cada capa oculta
                                        verbose=True,               #o la politica detrás del numero de iteraciones
                                        n_iter_no_change=1000)

#Entrenamos al modelo
modelo.fit(X, Y)

#Si queremos hacer predicciones
#model.predict(Xp)

#Lo bueno de esta libreria es que todas las redes tienen la misma estructura
#primero se crea el modelo, luego se entrena y por último se hacen prediccciones
#por lo que es muy facil usar diferentes arquitecturas
# Out:
# Iteration 1, loss = 0.79052479
# Iteration 2, loss = 0.65557128
# Iteration 3, loss = 0.47929117
# Iteration 4, loss = 0.32247167
# Iteration 5, loss = 0.20536796
# Iteration 6, loss = 0.14606239
# Iteration 7, loss = 0.12572042
# Iteration 8, loss = 0.13068478
# Iteration 9, loss = 0.14082224
# Iteration 10, loss = 0.14580817
# Iteration 11, loss = 0.14391996
# Iteration 12, loss = 0.13825833
# Iteration 13, loss = 0.13183031
# Iteration 14, loss = 0.12798379
# Iteration 15, loss = 0.12540624
# Iteration 16, loss = 0.12470196
# Iteration 17, loss = 0.12496981
# Iteration 18, loss = 0.12510644
# Iteration 19, loss = 0.12534204
# Iteration 20, loss = 0.12526925
# Iteration 21, loss = 0.12509793
# Iteration 22, loss = 0.12490669
# Iteration 23, loss = 0.12483043
# Iteration 24, loss = 0.12455121
# Iteration 25, loss = 0.12448316
# Iteration 26, loss = 0.12444905
# Iteration 27, loss = 0.12440076
# Iteration 28, loss = 0.12437184
# Iteration 29, loss = 0.12434800
# ...
